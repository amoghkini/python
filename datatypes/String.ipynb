# %% [markdown]
# ### Creating string

# %%
a = 'amogh'
print(a)
# Out:
# amogh

# %%
a = "AMOGH"
print(a)
# Out:
# AMOGH

# %%
 "it's raining outside"
# Out:
# "it's raining outside"

# %%
c = '''hello'''      # For multiline strings
print(c)
# Out:
# hello

# %%
c = str("Hello")
print(c)
# Out:
# Hello

# %% [markdown]
# ### Accessing a substring from a string

# %% [markdown]
# #### Concept of indexing

# %%
c = "AMOGH"
print(c[0])
# Out:
# A

# %%
print(c[-1])
# Out:
# H

# %% [markdown]
# #### concept of slicing

# %%
a = "Hello world"

print(a[0:5])
# Out:
# Hello

# %%
print(a[3:])
# Out:
# lo world

# %%
print(a[:3])
# Out:
# Hel

# %%
print(a[:])
# Out:
# Hello world

# %%
print(a[2:7:2])
# Out:
# low

# %%
print(a[0:6:-1])

# %%
print(a[-5:-1:2])
# Out:
# wr

# %%
print(a[::-1])
# Out:
# dlrow olleH

# %% [markdown]
# ### Editing and deleting a string in python

# %% [markdown]
# #### Editing

# %%
c = 'Hello'
print(c)
# Out:
# Hello

# %%
c[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0ea9ccfabf06> in <module>
# ----> 1 c[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### Strings are immutable/non editable. we can change someting and assign new string to same variable

# %%
c = "world"
print(c)
# Out:
# world

# %% [markdown]
# #### Deleting

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-1dd5973cae19> in <module>
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %% [markdown]
# ### String operations

# %% [markdown]
# #### 1. Arithmetic opertors

# %%
##    (+) operator - String concatinate
"hello " + "World"
# Out:
# 'hello World'

# %%
##   (*) multiplication
"Hello " * 4
# Out:
# 'Hello Hello Hello Hello '

# %% [markdown]
# #### 2. Relational operators

# %%
"Hwllo" == "World"
# Out:
# False

# %%
"Hello" != "World"
# Out:
# True

# %%
"Mumbai" > "Pune"

## Comparision happens lexiographically(As per dictionary)
# Out:
# False

# %%
"Goa" < "Kolkata"
# Out:
# True

# %%
"kal" > "Kal"

## Small letters comes after capital letters
# Out:
# True

# %% [markdown]
# #### 3. Logical operators

# %%
"Hello" and "World"
# Out:
# 'World'

# %% [markdown]
# "" --> False  <br>
# "Something" --> True

# %%
"" and "amogh"
# Out:
# ''

# %%
"Hello" and "world"
# Out:
# 'world'

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
not "Hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %% [markdown]
# #### 4. Loops on string

# %%
c = "Hello world"

for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# #### 5. Membership Operations

# %%
c = "Hello world"

# %%
"H" in c
# Out:
# True

# %%
"h" in c
# Out:
# False

# %% [markdown]
# ### String Functions

# %% [markdown]
# #### a) Common funcctions

# %% [markdown]
# ##### 1. len()

# %%
c ="Amogh"
print(len(c))
# Out:
# 5

# %% [markdown]
# ##### 2. max()

# %%
max(c)
# Out:
# 'o'

# %% [markdown]
# ##### 3. min()

# %%
min(c)
# Out:
# 'A'

# %% [markdown]
# ##### 4. sorted()

# %%
sorted(c)
# Out:
# ['A', 'g', 'h', 'm', 'o']

# %%
sorted(c,reverse=True)
# Out:
# ['o', 'm', 'h', 'g', 'A']

# %% [markdown]
# #### b) Capitalize,Title,Upper,lower,Swapcase        (strings present only in string)

# %%
c = "mumbai"

# %%
c.capitalize()
# Out:
# 'Mumbai'

# %%
c   # It will not change original string
# Out:
# 'mumbai'

# %%
"my name is amogh".capitalize()
# Out:
# 'My name is amogh'

# %%
"my name is amogh".title()
# Out:
# 'My Name Is Amogh'

# %%
"my name is amogh".upper()
# Out:
# 'MY NAME IS AMOGH'

# %%
"my name is amogh".lower()
# Out:
# 'my name is amogh'

# %%
a = "AmOgH"

# %%
a.swapcase()
# Out:
# 'aMoGh'

# %% [markdown]
# #### c) count()

# %%
"My name is amogh".count("a")
# Out:
# 2

# %%
"My name is amogh".count("amo")
# Out:
# 1

# %% [markdown]
# #### d) Find/index: find returns -1 if substring not found but index throws an error

# %%
"My name is amogh".find("a")
# Out:
# 4

# %%
"My name is amogh".find("v")
# Out:
# -1

# %%
"My name is amogh".index("a")
# Out:
# 4

# %%
"My name is amogh".index("v")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-e4301f7cfdc7> in <module>
# ----> 1 "My name is amogh".index("v")
#
# ValueError: substring not found

# %% [markdown]
# #### e) endswith/startswith

# %%
"My name is amogh".endswith("ogh")
# Out:
# True

# %%
"My name is amogh".startswith("My ")
# Out:
# True

# %%
"My name is amogh".startswith("my ")
# Out:
# False

# %% [markdown]
# #### f) format

# %%
"My name is {} and i am {}.".format('Amogh',19)
# Out:
# 'My name is Amogh and i am 19 year old'

# %%
"My name is {1} and i am {0}.".format('Amogh',19)
# Out:
# 'My name is 19 and i am Amogh.'

# %%
"My name is {name} and i am {age}.".format(name='Amogh',age=19)
# Out:
# 'My name is Amogh and i am 19.'

# %% [markdown]
# #### g) isalnum/asalpha/isdecimal/isdigit/isidentifier

# %%
"abc20".isalnum()
# Out:
# True

# %%
"asda123%".isalnum()
# Out:
# False

# %%
"abc02".isalnum()
# Out:
# True

# %%
"0222".isdigit()
# Out:
# True

# %%
"Hello world".isidentifier()
# Out:
# False

# %%
"Hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# #### h) split

# %%
"Who is prime ministor of India".split()
# Out:
# ['Who', 'is', 'prime', 'ministor', 'of', 'India']

# %%
"Who is prime ministor of India".split('i')
# Out:
# ['Who ', 's pr', 'me m', 'n', 'stor of Ind', 'a']

# %%
"Who is prime ministor of India".split('x')
# Out:
# ['Who is prime ministor of India']

# %% [markdown]
# #### i) join()

# %%
"".join(['Who', 'is', 'prime', 'ministor', 'of', 'India'])
# Out:
# 'WhoisprimeministorofIndia'

# %%
" ".join(['Who', 'is', 'prime', 'ministor', 'of', 'India'])
# Out:
# 'Who is prime ministor of India'

# %% [markdown]
# #### j) replace

# %%
"My name is ABC".replace("ABC","XYZ")
# Out:
# 'My name is XYZ'

# %% [markdown]
# #### k) strip() - it removes trailing and leading spaces

# %%
name  = "                       amogh             "

# %%
"hi" + name
# Out:
# 'hi                       amogh             '

# %%
name.strip()
# Out:
# 'amogh'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...
