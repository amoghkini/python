# %% [markdown]
# ### 1. Create

# %%
t1 = tuple()

# %%
t2 = ()

# %%
t3 = (1,2,2,3,4,4)

# %%
t4 = 100,

# %%
type(t4)
# Out:
# tuple

# %%
t5 = ("asad",)
print(type(t5))
# Out:
# <class 'tuple'>

# %% [markdown]
# ### 2. Access

# %%
## same as list

# %% [markdown]
# ### 3. Edit

# %%
## tuple is immutable so we can not edit them

# %% [markdown]
# ### 4. Add

# %%
## tuple is immutable so we can not edit them

# %% [markdown]
# ### 5. Delete

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5db19043943a> in <module>
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
del t2[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-44fdbce93b46> in <module>
# ----> 1 del t2[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ### 6. Operations

# %%
t3 + t5
# Out:
# (100, 'asad')

# %% [markdown]
# ### 7. Functions

# %%
len(t3)
# Out:
# 1

# %%
## same as list
